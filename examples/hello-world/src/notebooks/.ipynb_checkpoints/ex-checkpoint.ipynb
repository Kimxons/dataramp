# %%
# This is a sample project created using dataramp

# Dataramp simplifies the way you structure your data science projects
# After installation, simpy run 'dr.core.create_project("your-project-name")' to get started

# %%
import warnings

warnings.filterwarnings('ignore')

import pandas as pd
import dataramp as dr

# %%
print(dr.__version__) # check library version
# Out:
# 0.1.8.deva55a370

# %%
# Some of the built-in functionalities in dataramp you can use
from dataramp.utils import (
    describe_df,
    display_missing,
    feature_summary,
    get_cat_vars,
    get_num_vars,
    get_unique_counts,
)

# %%
from sklearn.datasets import load_iris

# %%
# Load your dataset
# df = pd.read_csv("../../datasets/raw/iris.csv")

# %%
iris = load_iris()

# %%
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target, name='species')

# %%
# X['id'] = range(len(X))
# X['species'] = y

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    id  species
# 0   0        0
# 1   1        0
# 2   2        0
# 3   3        0
# 4   4        0

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %%
df = pd.concat([X, y], axis=1)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    id  species  species
# 0   0        0        0
# 1   1        0        0
# 2   2        0        0
# 3   3        0        0
# 4   4        0        0

# %%
display_missing(df, plot=False)
# Out:
#             variable  missing_count  missing_percent
# 0  sepal length (cm)              0              0.0
# 1   sepal width (cm)              0              0.0
# 2  petal length (cm)              0              0.0
# 3   petal width (cm)              0              0.0
# 4                 id              0              0.0
# 5            species              0              0.0
# 6            species              0              0.0

# %%
describe_df(df.select_dtypes(include=['number'])) # description of the numerical variables
# Out:
#                    count       mean        std  min    25%    50%     75%  \
# sepal length (cm)  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40
# sepal width (cm)   150.0   3.057333   0.435866  2.0   2.80   3.00    3.30
# petal length (cm)  150.0   3.758000   1.765298  1.0   1.60   4.35    5.10
# petal width (cm)   150.0   1.199333   0.762238  0.1   0.30   1.30    1.80
# id                 150.0  74.500000  43.445368  0.0  37.25  74.50  111.75
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
#
#                      max
# sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# id                 149.0
# species              2.0
# species              2.0
# species              2.0
# species              2.0

# %%
describe_df(df.select_dtypes(include=['number'])) # description of the categorical variables
# Out:
#                    count       mean        std  min    25%    50%     75%  \
# sepal length (cm)  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40
# sepal width (cm)   150.0   3.057333   0.435866  2.0   2.80   3.00    3.30
# petal length (cm)  150.0   3.758000   1.765298  1.0   1.60   4.35    5.10
# petal width (cm)   150.0   1.199333   0.762238  0.1   0.30   1.30    1.80
# id                 150.0  74.500000  43.445368  0.0  37.25  74.50  111.75
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
# species            150.0   1.000000   0.819232  0.0   0.00   1.00    2.00
#
#                      max
# sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# id                 149.0
# species              2.0
# species              2.0
# species              2.0
# species              2.0

# %%
feature_summary(df.select_dtypes(include=['number']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4142835/1418785068.py in ?()
# ----> 1 feature_summary(df.select_dtypes(include=['number']))
#
# ~/workspace/venv/lib/python3.10/site-packages/dataramp/utils.py in ?(df, visualize)
#     314             summary_df.at[col, "Unique_Count"] = df[col].nunique()
#     315             summary_df.at[col, "Data_type"] = "categorical"
#     316         else:
#     317             summary_df.at[col, "Unique_Count"] = df[col].nunique()
# --> 318             summary_df.at[col, "Data_type"] = str(df[col].dtype)
#     319             summary_df.at[col, "Max"] = df[col].max()
#     320             summary_df.at[col, "Min"] = df[col].min()
#     321             summary_df.at[col, "Mean"] = df[col].mean()
#
# ~/workspace/venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
get_cat_vars(df)

# %%
get_num_vars(df)

# %%
get_unique_counts(df)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

X_scaled = StandardScaler().fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from dataramp.utils import check_train_test_set

# %%
check_train_test_set(
    train_data=X_train, 
    test_data=X_test, 
    index=None, 
    col=None
)

# %%
X_test
